# %% [markdown]
# # Load Data & Train Model
# This notebook allows us to load the entire dataset, split it into a proper train/test split and trains the model using K-Fold cross validation.
#
# ## Imports

# %%
# Essentials
import math
import random
import os
import copy
import glob
import shutil
import numpy as np
import json
import importlib
import time as time

# Torch
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import Sequential as Seq, Linear as Lin, Conv2d

import torchvision.models as models
from torchvision import datasets, transforms

from torch.utils.data import Dataset, DataLoader

import torch.optim as optim
import timm
from timm.models import create_model
from timm.data import create_transform
from sklearn.metrics import accuracy_score

# Images
import albumentations
import albumentations.pytorch

import cv2

from PIL import Image

# Machine Learning
from sklearn.model_selection import KFold

from barbar import Bar

import utils
importlib.reload(utils)

from utils import get_data, select_gpu, get_model, get_class_weigths, get_files
from utils import My_data, CustomTransforms

# %% [markdown]
# ## Set Device

# %%
device = torch.device(f"cuda:{select_gpu()}" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Selecting GPU 0 with 14907MB free memory
# Using device: cuda:0

# %%
torch.cuda.device_count()
# Out:
# 2

# %%
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print(torch.cuda.memory_summary(device=None, abbreviated=False))
    torch.cuda.manual_seed(42)
    torch.cuda.manual_seed_all(42)
    torch.backends.cudnn.benchmark = True
    torch.backends.cudnn.deterministic = False
# Out:
# |===========================================================================|
# |                  PyTorch CUDA memory summary, device ID 0                 |
# |---------------------------------------------------------------------------|
# |            CUDA OOMs: 0            |        cudaMalloc retries: 0         |
# |===========================================================================|
# |        Metric         | Cur Usage  | Peak Usage | Tot Alloc  | Tot Freed  |
# |---------------------------------------------------------------------------|
# | Allocated memory      |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Active memory         |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | GPU reserved memory   |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Non-releasable memory |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from large pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |       from small pool |       0 B  |       0 B  |       0 B  |       0 B  |
# |---------------------------------------------------------------------------|
# | Allocations           |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Active allocs         |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | GPU reserved segments |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Non-releasable allocs |       0    |       0    |       0    |       0    |
# |       from large pool |       0    |       0    |       0    |       0    |
# |       from small pool |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize allocations  |       0    |       0    |       0    |       0    |
# |---------------------------------------------------------------------------|
# | Oversize GPU segments |       0    |       0    |       0    |       0    |
# |===========================================================================|

# %% [markdown]
# ## Load Dataset

# %% [markdown]
# This downloads the dataset to the server and unzips it so we can use it. Check the size of the folder before running the rest of the code. Should be around 4GB

# %%
# All eight classes
classes = ["A", "F", "TA", "PT", "DC", "LC", "MC", "PC"]
benign_classes = classes[:4]
malignant_classes = classes[4:]

# All four zoom levels
zooms = ["40", "100", "200", "400"]


# Load train and test files that are used for the model.
train_dict, test_dict = get_data(os.path.join(os.getcwd(), "BreaKHis_v1"))
train_files = "./dataset/train/original/**/**/*.png"
# Out:
# Opening /home/jovyan/txt/train.txt.txt
# Opening /home/jovyan/txt/test.txt.txt

# %% [markdown]
# ## Prepare Data
# In this section we do the following:
# 1. Store all image paths in a dictionary that is filtered on class and zoom level
# 2. Create a stratified train/test split (based on class and zoom level) and store the image paths of both sets again in a filtered dictionary
# 3. Copy all images from the raw data source to the structured data folder "dataset/"
# 4. Create a 5-fold cross validation split for the train dataset
# 5. Prepare all splits for forward pass of the model

# %% [markdown]
# ### Prepare Data for Forward Pass

# %%
# initialize transformers
transform = CustomTransforms()

# Create data loaders for each fold
train_dataloader = DataLoader(My_data(get_files(train_files), transforms=transform.get_transform("train")), batch_size=4,shuffle=True,num_workers=2, pin_memory=True,prefetch_factor=2)

# %% [markdown]
# ## Create Model

# %%
model_name = "swin"
model = get_model(device, model=model_name)

# %%
print(len([param for param in model.named_parameters()]))

# Iterate over the parameters and check requires_grad
for name, param in model.named_parameters():
    if param.requires_grad:
        print(f"Parameter '{name}' requires grad.")
    else:
        print(f"Parameter '{name}' does not require grad.")
    
    param.requires_grad = True
# Out:
# 62
# Parameter 'conv1.weight' requires grad.
# Parameter 'bn1.weight' requires grad.
# Parameter 'bn1.bias' requires grad.
# Parameter 'layer1.0.conv1.weight' requires grad.
# Parameter 'layer1.0.bn1.weight' requires grad.
# Parameter 'layer1.0.bn1.bias' requires grad.
# Parameter 'layer1.0.conv2.weight' requires grad.
# Parameter 'layer1.0.bn2.weight' requires grad.
# Parameter 'layer1.0.bn2.bias' requires grad.
# Parameter 'layer1.1.conv1.weight' requires grad.
# Parameter 'layer1.1.bn1.weight' requires grad.
# Parameter 'layer1.1.bn1.bias' requires grad.
# Parameter 'layer1.1.conv2.weight' requires grad.
# Parameter 'layer1.1.bn2.weight' requires grad.
# Parameter 'layer1.1.bn2.bias' requires grad.
# Parameter 'layer2.0.conv1.weight' requires grad.
# Parameter 'layer2.0.bn1.weight' requires grad.
# Parameter 'layer2.0.bn1.bias' requires grad.
# Parameter 'layer2.0.conv2.weight' requires grad.
# Parameter 'layer2.0.bn2.weight' requires grad.
# Parameter 'layer2.0.bn2.bias' requires grad.
# Parameter 'layer2.0.downsample.0.weight' requires grad.
# Parameter 'layer2.0.downsample.1.weight' requires grad.
# Parameter 'layer2.0.downsample.1.bias' requires grad.
# Parameter 'layer2.1.conv1.weight' requires grad.
# Parameter 'layer2.1.bn1.weight' requires grad.
# Parameter 'layer2.1.bn1.bias' requires grad.
# Parameter 'layer2.1.conv2.weight' requires grad.
# Parameter 'layer2.1.bn2.weight' requires grad.
# Parameter 'layer2.1.bn2.bias' requires grad.
# Parameter 'layer3.0.conv1.weight' requires grad.
# Parameter 'layer3.0.bn1.weight' requires grad.
# Parameter 'layer3.0.bn1.bias' requires grad.
# Parameter 'layer3.0.conv2.weight' requires grad.
# Parameter 'layer3.0.bn2.weight' requires grad.
# Parameter 'layer3.0.bn2.bias' requires grad.
# Parameter 'layer3.0.downsample.0.weight' requires grad.
# Parameter 'layer3.0.downsample.1.weight' requires grad.
# Parameter 'layer3.0.downsample.1.bias' requires grad.
# Parameter 'layer3.1.conv1.weight' requires grad.
# Parameter 'layer3.1.bn1.weight' requires grad.
# Parameter 'layer3.1.bn1.bias' requires grad.
# Parameter 'layer3.1.conv2.weight' requires grad.
# Parameter 'layer3.1.bn2.weight' requires grad.
# Parameter 'layer3.1.bn2.bias' requires grad.
# Parameter 'layer4.0.conv1.weight' requires grad.
# Parameter 'layer4.0.bn1.weight' requires grad.
# Parameter 'layer4.0.bn1.bias' requires grad.
# Parameter 'layer4.0.conv2.weight' requires grad.
# Parameter 'layer4.0.bn2.weight' requires grad.
# Parameter 'layer4.0.bn2.bias' requires grad.
# Parameter 'layer4.0.downsample.0.weight' requires grad.
# Parameter 'layer4.0.downsample.1.weight' requires grad.
# Parameter 'layer4.0.downsample.1.bias' requires grad.
# Parameter 'layer4.1.conv1.weight' requires grad.
# Parameter 'layer4.1.bn1.weight' requires grad.
# Parameter 'layer4.1.bn1.bias' requires grad.
# Parameter 'layer4.1.conv2.weight' requires grad.
# Parameter 'layer4.1.bn2.weight' requires grad.
# Parameter 'layer4.1.bn2.bias' requires grad.
# Parameter 'fc.weight' requires grad.
# Parameter 'fc.bias' requires grad.

# %%
class FocalLoss(nn.Module):
    def __init__(self, gamma=2.0, class_weights=None):
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        self.class_weights = class_weights

    def forward(self, logits, labels):
        probs = torch.sigmoid(logits)
        ce_loss = nn.BCELoss()(probs, labels)
        # print(type(probs), probs, self.gamma)
        weight = (1 - probs).pow(self.gamma)
        loss = ce_loss  # Initialize loss with cross-entropy loss
        if self.class_weights is not None:
            weight = weight * self.class_weights
            loss = loss * weight
        return loss

# %% [markdown]
# ## Train Model
#
# This section performs the actual training of the model. We first determine methods fit and validate that will be called during the training. Afterwards, we define the loop that optimizes the model.

# %%
def fit(model, dataloader, optimizer,scheduler, criterion):
    #print('Training')
    model.train()
    train_running_loss = 0.0
    train_running_correct = 0
    accum_iter = 4

    for i, (inputs, labels) in enumerate(Bar(dataloader)):
        inputs = inputs.to(device)
        labels = labels.float().to(device)
        optimizer.zero_grad()
        #model.zero_grad(set_to_none=True)
        # Forward pass - compute outputs on input data using the model
        outputs = model(inputs)
        thresholds = [0.5, 0.5, 0.5,0.5,0.5,0.5,0.5,0.5]
        # Compute loss
        loss = criterion(outputs, labels)
        train_running_loss += loss.item()* inputs.size(0)
        # _ , preds = torch.max(outputs.data, 1)
        # Apply sigmoid activation to obtain probabilities
        #preds = (outputs > 0.5).float()
        probs = torch.sigmoid(outputs)
        preds = torch.zeros_like(probs)

        # Set predicted labels based on the threshold
        for i, threshold in enumerate(thresholds):
            preds[:, i] = (probs[:, i] >= threshold).float()
        train_running_correct += (preds == labels).all(dim=1).float().sum()
        # Backpropagate the gradients
        loss /= accum_iter
        loss.backward()

        if ((i + 1) % accum_iter == 0) :
            optimizer.step()
            optimizer.zero_grad()

    scheduler.step()

    train_loss = train_running_loss/len(dataloader.dataset)
    train_accuracy = 100. * train_running_correct/len(dataloader.dataset)
    return train_loss, train_accuracy

# %%
history=[]

if torch.cuda.is_available():
    torch.cuda.empty_cache()

model = model.to(device)

class_weights = get_class_weigths(train_dict).to(device)
class_weights = class_weights.to(device)

criterion = FocalLoss(class_weights)

optimizer = optim.AdamW(filter(lambda p: p.requires_grad, model.parameters()), lr=1e-4)

scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=15, gamma=0.5)

best_acc = 0.0
epochs=50

for epoch in range(epochs):
    epoch_start = time.time()
    print('Epoch-{0}/{1} lr: {2}'.format(epoch+1,epochs ,optimizer.param_groups[0]['lr']))
    
    # # Why is this here???
    # if  epoch > 14:
    #     for param in model.parameters():
    #         param.requires_grad = True
    #print(f"Epoch {epoch+1} of {epochs}")
    train_epoch_loss, train_epoch_accuracy = fit(model,train_dataloader,optimizer,scheduler,criterion)


    epoch_end = time.time()
    history.append([epoch+1,train_epoch_loss, train_epoch_accuracy,(epoch_end-epoch_start)])
    print(f"Train Loss: {train_epoch_loss:.4f}, Train Acc: {train_epoch_accuracy:.2f},time : {epoch_end-epoch_start:.2f}")
    torch.save({'history':history}, f'models/Master_{model_name}_his.pth')
    if train_epoch_accuracy > best_acc:
        best_acc = train_epoch_accuracy
        best_model_wts = copy.deepcopy(model.state_dict())

        best_epoch=epoch
        torch.save({
            'epoch': epoch+1,
            'model_state_dict': best_model_wts,
            'loss': criterion,
            'history':history,
            'best_epoch': best_epoch+1,

            }, f'models/Master_{model_name}.pth')
# Out:
# Epoch-1/50 lr: 0.0001
# 5694/5694: [===============================>] - ETA 3.1ssss
# Train Loss: 0.3017, Train Acc: 28.03,Val Loss: 0.2696, Val Acc: 33.24,time : 102.22
# Epoch-2/50 lr: 0.0001
# 5694/5694: [===============================>] - ETA 0.2sss
# Train Loss: 0.2775, Train Acc: 29.89,Val Loss: 0.2585, Val Acc: 37.90,time : 101.69
# Epoch-3/50 lr: 0.0001
# 5694/5694: [===============================>] - ETA 0.3sss
# Train Loss: 0.2699, Train Acc: 31.77,Val Loss: 0.2618, Val Acc: 46.45,time : 106.77
# Epoch-4/50 lr: 0.0001
# 5694/5694: [===============================>] - ETA 0.2sss
# Train Loss: 0.2635, Train Acc: 33.18,Val Loss: 0.2541, Val Acc: 51.25,time : 102.99
# Epoch-5/50 lr: 0.0001
# 5694/5694: [===============================>] - ETA 0.2sss
# Train Loss: 0.2539, Train Acc: 35.34,Val Loss: 0.2444, Val Acc: 46.80,time : 104.47
# Epoch-6/50 lr: 0.0001
# 5694/5694: [===============================>] - ETA 0.2sss
# Train Loss: 0.2459, Train Acc: 37.23,Val Loss: 0.2907, Val Acc: 39.43,time : 106.05
# Epoch-7/50 lr: 0.0001
# 5694/5694: [===============================>] - ETA 0.2sss
# Train Loss: 0.2416, Train Acc: 38.88,Val Loss: 0.2136, Val Acc: 50.90,time : 105.65
# Epoch-8/50 lr: 0.0001
# 5694/5694: [===============================>] - ETA 0.2sss
# Train Loss: 0.2323, Train Acc: 40.89,Val Loss: 0.2361, Val Acc: 50.00,time : 109.70
# Epoch-9/50 lr: 0.0001
# 5694/5694: [===============================>] - ETA 0.2sss
# Train Loss: 0.2256, Train Acc: 42.22,Val Loss: 0.1993, Val Acc: 57.16,time : 111.36
# Epoch-10/50 lr: 0.0001
# 5694/5694: [===============================>] - ETA 0.2sss
# Train Loss: 0.2201, Train Acc: 44.56,Val Loss: 0.2201, Val Acc: 52.16,time : 117.23
# Epoch-11/50 lr: 0.0001
# 5698/5698: [===============================>] - ETA 0.2sss
# Train Loss: 0.2161, Train Acc: 45.16,Val Loss: 0.2093, Val Acc: 54.67,time : 106.90
# Epoch-12/50 lr: 0.0001
# 5698/5698: [===============================>] - ETA 0.2sss
# Train Loss: 0.2109, Train Acc: 46.28,Val Loss: 0.2488, Val Acc: 45.12,time : 115.16
# Epoch-13/50 lr: 0.0001
# 5698/5698: [===============================>] - ETA 0.2sss
# Train Loss: 0.2079, Train Acc: 47.23,Val Loss: 0.2199, Val Acc: 50.49,time : 118.36
# Epoch-14/50 lr: 0.0001
# 5698/5698: [===============================>] - ETA 0.2sss
# Train Loss: 0.2043, Train Acc: 48.54,Val Loss: 0.2073, Val Acc: 53.56,time : 198.22
# Epoch-15/50 lr: 0.0001
# 5698/5698: [===============================>] - ETA 0.3sss
# Train Loss: 0.2010, Train Acc: 49.79,Val Loss: 0.1763, Val Acc: 61.44,time : 128.48
# Epoch-16/50 lr: 5e-05
# 5698/5698: [===============================>] - ETA 0.2sss
# Train Loss: 0.1871, Train Acc: 53.37,Val Loss: 0.1785, Val Acc: 63.74,time : 95.80
# Epoch-17/50 lr: 5e-05
# 5698/5698: [===============================>] - ETA 0.2sss
# Train Loss: 0.1848, Train Acc: 53.55,Val Loss: 0.1752, Val Acc: 61.99,time : 99.62
# Epoch-18/50 lr: 5e-05
# 5698/5698: [===============================>] - ETA 0.2sss
# Train Loss: 0.1820, Train Acc: 54.19,Val Loss: 0.1793, Val Acc: 60.88,time : 104.54
# Epoch-19/50 lr: 5e-05
# 5698/5698: [===============================>] - ETA 0.2sss
# Train Loss: 0.1767, Train Acc: 55.79,Val Loss: 0.1714, Val Acc: 63.60,time : 100.69
# Epoch-20/50 lr: 5e-05
# 5698/5698: [===============================>] - ETA 0.2sss
# Train Loss: 0.1751, Train Acc: 55.97,Val Loss: 0.1766, Val Acc: 64.09,time : 98.46
# Epoch-21/50 lr: 5e-05
# 5704/5704: [===============================>] - ETA 0.2sss
# Train Loss: 0.1721, Train Acc: 57.05,Val Loss: 0.1585, Val Acc: 64.99,time : 102.69
# Epoch-22/50 lr: 5e-05
# 5704/5704: [===============================>] - ETA 0.2sss
# Train Loss: 0.1720, Train Acc: 57.14,Val Loss: 0.1741, Val Acc: 65.06,time : 99.59
# Epoch-23/50 lr: 5e-05
# 5704/5704: [===============================>] - ETA 0.2sss
# Train Loss: 0.1701, Train Acc: 57.89,Val Loss: 0.1704, Val Acc: 63.45,time : 98.34
# Epoch-24/50 lr: 5e-05
# 5704/5704: [===============================>] - ETA 0.2sss
# Train Loss: 0.1660, Train Acc: 58.77,Val Loss: 0.1873, Val Acc: 64.57,time : 104.68
# Epoch-25/50 lr: 5e-05
# 5704/5704: [===============================>] - ETA 0.2sss
# Train Loss: 0.1641, Train Acc: 59.55,Val Loss: 0.1587, Val Acc: 64.22,time : 104.10
# Epoch-26/50 lr: 5e-05
# 5704/5704: [===============================>] - ETA 0.2sss
# Train Loss: 0.1637, Train Acc: 58.82,Val Loss: 0.1725, Val Acc: 61.62,time : 101.75
# Epoch-27/50 lr: 5e-05
# 5704/5704: [===============================>] - ETA 0.2sss
# Train Loss: 0.1587, Train Acc: 61.13,Val Loss: 0.1569, Val Acc: 65.69,time : 107.89
# Epoch-28/50 lr: 5e-05
# 5704/5704: [===============================>] - ETA 0.2sss
# Train Loss: 0.1601, Train Acc: 60.99,Val Loss: 0.1808, Val Acc: 62.39,time : 102.51
# Epoch-29/50 lr: 5e-05
# 5704/5704: [===============================>] - ETA 0.2sss
# Train Loss: 0.1580, Train Acc: 61.54,Val Loss: 0.1525, Val Acc: 66.11,time : 108.36
# Epoch-30/50 lr: 5e-05
# 5704/5704: [===============================>] - ETA 0.2sss
# Train Loss: 0.1543, Train Acc: 61.89,Val Loss: 0.1404, Val Acc: 70.87,time : 105.74
# Epoch-31/50 lr: 2.5e-05
# 5713/5713: [===============================>] - ETA 0.3sss
# Train Loss: 0.1500, Train Acc: 63.21,Val Loss: 0.1590, Val Acc: 69.20,time : 103.11
# Epoch-32/50 lr: 2.5e-05
# 5713/5713: [===============================>] - ETA 0.2sss
# Train Loss: 0.1474, Train Acc: 64.34,Val Loss: 0.1673, Val Acc: 67.37,time : 105.96
# Epoch-33/50 lr: 2.5e-05
# 5713/5713: [===============================>] - ETA 0.2sss
# Train Loss: 0.1422, Train Acc: 66.02,Val Loss: 0.1641, Val Acc: 68.99,time : 104.87
# Epoch-34/50 lr: 2.5e-05
# 5713/5713: [===============================>] - ETA 0.1sss
# Train Loss: 0.1409, Train Acc: 65.59,Val Loss: 0.1580, Val Acc: 71.04,time : 103.59
# Epoch-35/50 lr: 2.5e-05
# 5713/5713: [===============================>] - ETA 0.2sss
# Train Loss: 0.1396, Train Acc: 66.18,Val Loss: 0.1635, Val Acc: 67.86,time : 111.06
# Epoch-36/50 lr: 2.5e-05
# 5713/5713: [===============================>] - ETA 0.2sss
# Train Loss: 0.1398, Train Acc: 66.30,Val Loss: 0.1626, Val Acc: 66.88,time : 104.41
# Epoch-37/50 lr: 2.5e-05
# 5713/5713: [===============================>] - ETA 0.2sss
# Train Loss: 0.1364, Train Acc: 67.09,Val Loss: 0.1755, Val Acc: 68.36,time : 100.57
# Epoch-38/50 lr: 2.5e-05
# 5713/5713: [===============================>] - ETA 0.2sss
# Train Loss: 0.1380, Train Acc: 66.73,Val Loss: 0.1657, Val Acc: 70.26,time : 103.59
# Epoch-39/50 lr: 2.5e-05
# 5713/5713: [===============================>] - ETA 0.2sss
# Train Loss: 0.1370, Train Acc: 67.06,Val Loss: 0.1610, Val Acc: 69.27,time : 103.55
# Epoch-40/50 lr: 2.5e-05
# 5713/5713: [===============================>] - ETA 0.2sss
# Train Loss: 0.1355, Train Acc: 67.30,Val Loss: 0.1567, Val Acc: 70.12,time : 108.42
# Epoch-41/50 lr: 2.5e-05
# 5719/5719: [===============================>] - ETA 0.2sss
# Train Loss: 0.1368, Train Acc: 66.38,Val Loss: 0.1422, Val Acc: 71.05,time : 105.52
# Epoch-42/50 lr: 2.5e-05
# 5719/5719: [===============================>] - ETA 0.2sss
# Train Loss: 0.1354, Train Acc: 67.58,Val Loss: 0.1332, Val Acc: 72.82,time : 98.14
# Epoch-43/50 lr: 2.5e-05
# 5719/5719: [===============================>] - ETA 0.2sss
# Train Loss: 0.1325, Train Acc: 67.84,Val Loss: 0.1232, Val Acc: 74.73,time : 106.81
# Epoch-44/50 lr: 2.5e-05
# 5719/5719: [===============================>] - ETA 0.2sss
# Train Loss: 0.1331, Train Acc: 68.18,Val Loss: 0.1302, Val Acc: 72.68,time : 98.50
# Epoch-45/50 lr: 2.5e-05
# 5719/5719: [===============================>] - ETA 0.3sss
# Train Loss: 0.1310, Train Acc: 68.72,Val Loss: 0.1304, Val Acc: 75.65,time : 98.69
# Epoch-46/50 lr: 1.25e-05
# 5719/5719: [===============================>] - ETA 0.2sss
# Train Loss: 0.1234, Train Acc: 70.69,Val Loss: 0.1317, Val Acc: 72.68,time : 103.03
# Epoch-47/50 lr: 1.25e-05
# 5719/5719: [===============================>] - ETA 0.2sss
# Train Loss: 0.1248, Train Acc: 69.91,Val Loss: 0.1518, Val Acc: 72.61,time : 99.50
# Epoch-48/50 lr: 1.25e-05
# 5719/5719: [===============================>] - ETA 0.2sss
# Train Loss: 0.1223, Train Acc: 70.06,Val Loss: 0.1538, Val Acc: 73.60,time : 100.15
# Epoch-49/50 lr: 1.25e-05
# 5719/5719: [===============================>] - ETA 0.2sss
# Train Loss: 0.1233, Train Acc: 70.17,Val Loss: 0.1483, Val Acc: 71.97,time : 102.61
# Epoch-50/50 lr: 1.25e-05
# 5719/5719: [===============================>] - ETA 0.2sss
# Train Loss: 0.1219, Train Acc: 70.24,Val Loss: 0.1204, Val Acc: 76.79,time : 100.40
